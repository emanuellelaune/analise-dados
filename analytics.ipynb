# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import os

# %%
df = pd.read_excel(r"C:\Users\ResTIC16\Downloads\Cópia de planilha_final(1) (1).xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433588 entries, 0 to 433587
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID_CLIENTE           433588 non-null  int64
#  1   SITUACAO             433588 non-null  object
#  2   ULTIMO_CORTE_INAD    37402 non-null   datetime64[ns]
#  3   ULTIMO_CANCELAMENTO  2777 non-null    datetime64[ns]
#  4   DATA_REGISTRO        433588 non-null  datetime64[ns]
#  5   CODIGO               433588 non-null  int64
#  6   PROTOCOLO            433588 non-null  int64
#  7   CANAL                433588 non-null  object
#  8   CIDADE_x             433588 non-null  object
#  9   BAIRRO_x             433570 non-null  object
#  10  TAB_N1               433588 non-null  object
#  11  TAB_N2               433588 non-null  object
#  12  TAB_N3               433562 non-null  object
#  13  SOLICITACAO          433356 non-null  object
# ...

# %%
df.drop(columns=['CODIGO', 'PROTOCOLO', 'CIDADE_y', 'BAIRRO_y', 'GEROU_OS', inplace=True)
# Out:
#   Cell In[8], line 1
#     df.drop(columns=['CODIGO', 'PROTOCOLO', 'CIDADE_y', 'BAIRRO_y', 'GEROU_OS', inplace=True)
#                                                                                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df.value_counts('SITUACAO')
# Out:
# SITUACAO
# LIGADO       393630
# DESLIGADO     39958
# Name: count, dtype: int64

# %%
df_backup = df.copy()          # cria uma cópia de segurança

# %%
print(os.path.abspath("dados_churn_limpo.xlsx"))
# Out:
# <module 'ntpath' (frozen)>

# %%
df.describe()

# %%
df.to_excel("dados_churn_limpo.xlsx", index=False)

# %%
import os

# %%
print(os.path.abspath("dados_churn_limpo.xlsx"))

# %%
le = LabelEncoder()

# %%
df["CIDADE_cod"] = le.fit_transform(df["CIDADE_x"])
mapeamento = dict(zip(le.classes_, le.transform(le.classes_) + 1))
print("Mapeamento:", mapeamento)

# %%
df["CANAL_cod"] = le.fit_transform(df["CANAL"])
mapeamento = dict(zip(le.classes_, le.transform(le.classes_) + 1))
print("Mapeamento:", mapeamento)

# %%
df.drop(columns=["CANAL", "CIDADE_x"], inplace=True)

# %%
print(os.getcwd())
# Out:
# C:\Users\ResTIC16\PyCharmMiscProject
