# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import os

# %%
df = pd.read_excel(r"C:\Users\ResTIC16\Downloads\Pasta2 (6).xlsx")

# %%
#df.info
# Out:
# <bound method DataFrame.info of          ID_CLIENTE   SITUACAO  ULTIMO_CORTE_INAD  ULTIMO_CANCELAMENTO  \
# 0               1.0     LIGADO                NaN                  NaN
# 1              31.0     LIGADO                NaN                  NaN
# 2              89.0     LIGADO                NaN                  NaN
# 3             120.0     LIGADO                NaN                  NaN
# 4             142.0  DESLIGADO            45960.0                  NaN
# ...             ...        ...                ...                  ...
# 1048570         NaN        NaN                NaN                  NaN
# 1048571         NaN        NaN                NaN                  NaN
# 1048572         NaN        NaN                NaN                  NaN
# 1048573         NaN        NaN                NaN                  NaN
# 1048574         NaN        NaN                NaN                  NaN
#
#             CANAL  CIDADE_x       BAIRRO_x                    TAB_N1 GENERO  \
# ...

# %%
# nome da coluna que tu quer analisar
coluna = "CIDADE_x"

# mostra so os valores únicos (sem repetição e sem vazios)
valores_unicos = df[coluna].dropna().unique()

# imprime cada valor único
for valor in valores_unicos:
    print(valor)
# Out:
# SÃO LUÍS
# SÃO JOSÉ DE RIBAMAR
# ITAPECURU MIRIM
# PAÇO DO LUMIAR
# RAPOSA
# CHAPADINHA
# VARGEM GRANDE
# SANTA RITA
# BARREIRINHAS
# ROSÁRIO
# SANTA INÊS
# BACABEIRA
